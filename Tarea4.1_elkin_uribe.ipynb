# %% [markdown]
# # <span style="color:red"><center>Tarea 4</center></span>
# ### <span style="color:green"><justify>por: Elkin Uribe</justify></span>

# %% [markdown]
# <span style="color:green"><justify>1. Consiga el conjunto de datos iris.csv. En el repositorio de Aprendizaje Profundo encuentra alguna versión.
# 2. Escriba una clase iterable que tenga la siguiente funcionalidad
# 2.1 Al instanciar un objeto, lee el archivo de datos y lo coloca en un dataframe interno en la clase.
# 2.2. Cada vez que se le pidan datos, debe regresar los dos siguientes datos.
# 2.3 Entregue un error si los datos se han agotado Pruebe su clase</justify></span>

# %%
import pandas as pd

df = pd.read_csv('https://archive.ics.uci.edu/ml/'
        'machine-learning-databases/iris/iris.data', header=None)

df.tail()
# Out:
#        0    1    2    3               4
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.to_csv('iris.csv', index = False)

# %%
class MyIterable:
    def __init__(self, file_path):
        self.df = pd.read_csv(file_path)
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index >= len(self.df):
            raise StopIteration
        else:
            result = (self.df.iloc[self.index], self.df.iloc[self.index + 1])
            self.index += 2
            return result

# %%
# crear una instancia de MyIterable
my_iterable = MyIterable('iris.csv')

# iterar sobre los datos y mostrarlos
for data1, data2 in my_iterable:
    print(data1, data2)
# Out:
# 0            5.1
# 1            3.5
# 2            1.4
# 3            0.2
# 4    Iris-setosa
# Name: 0, dtype: object 0            4.9
# 1            3.0
# 2            1.4
# 3            0.2
# 4    Iris-setosa
# Name: 1, dtype: object
# 0            4.7
# 1            3.2
# 2            1.3
# 3            0.2
# 4    Iris-setosa
# Name: 2, dtype: object 0            4.6
# 1            3.1
# 2            1.5
# 3            0.2
# 4    Iris-setosa
# Name: 3, dtype: object
# 0            5.0
# 1            3.6
# 2            1.4
# 3            0.2
# 4    Iris-setosa
# Name: 4, dtype: object 0            5.4
# 1            3.9
# 2            1.7
# 3            0.4
# 4    Iris-setosa
# Name: 5, dtype: object
# 0            4.6
# 1            3.4
# 2            1.4
# 3            0.3
# 4    Iris-setosa
# Name: 6, dtype: object 0            5.0
# 1            3.4
# 2            1.5
# 3            0.2
# 4    Iris-setosa
# Name: 7, dtype: object
# 0            4.4
# 1            2.9
# ...
